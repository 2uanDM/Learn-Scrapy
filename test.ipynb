# %%
import pandas as pd

# %%
file_dir = r'C:\Users\Thinkbook 14 G3 ACL\Documents\GitHub\Kaxim-Stocks-Topic-2\Ty gia VCB_05102023.xlsx'

# %%
df = pd.read_excel(file_dir, engine='openpyxl')
# Out:
# c:\Users\Thinkbook 14 G3 ACL\Documents\GitHub\Kaxim-Stocks-Topic-2\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df = df.iloc[2:22]
# Rename columns
df.columns = ['Date', 'Currency', 'Buy', 'Transfer', 'Sell']
# Out:
#    Tỷ giá các ngoại tệ Ngân hàng TMCP Ngoại thương Việt Nam Unnamed: 1  \
# 2                                   AUSTRALIAN DOLLAR              AUD
# 3                                     CANADIAN DOLLAR              CAD
# 4                                         SWISS FRANC              CHF
# 5                                       YUAN RENMINBI              CNY
# 6                                        DANISH KRONE              DKK
# 7                                                EURO              EUR
# 8                                      POUND STERLING              GBP
# 9                                     HONGKONG DOLLAR              HKD
# 10                                       INDIAN RUPEE              INR
# 11                                                YEN              JPY
# 12                                         KOREAN WON              KRW
# 13                                      KUWAITI DINAR              KWD
# 14                                  MALAYSIAN RINGGIT              MYR
# 15                                   NORWEGIAN KRONER              NOK
# 16                                      RUSSIAN RUBLE              RUB
# 17                                         SAUDI RIAL              SAR
# 18                                      SWEDISH KRONA              SEK
# 19                                   SINGAPORE DOLLAR              SGD
# 20                                      THAILAND BAHT              THB
# 21                                          US DOLLAR              USD
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4
# 2    15111.79    15264.43    15755.15
# 3    17324.89    17499.89    18062.48
# 4    26011.99    26274.73    27119.42
# 5      3271.8     3304.85     3411.61
# 6           -     3379.08     3508.71
# 7    25009.66    25262.28    26382.69
# 8    28897.52    29189.41    30127.80
# 9     3036.27     3066.94     3165.54
# 10          -      292.21      303.91
# 11     159.72      161.34      169.08
# 12      15.66       17.40       19.08
# 13          -    78684.43    81835.45
# 14          -     5115.27     5227.17
# 15          -     2179.25     2271.92
# 16          -      235.63      260.86
# 17          -     6484.83     6744.52
# 18          -     2165.97     2258.08
# 19   17371.74    17547.21    18111.32
# 20     584.36      649.28      674.19
# 21      24190    24220.00    24560.00
